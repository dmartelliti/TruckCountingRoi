# %%
import json
from infrastructure.brokers.rabbitmq.publisher import RabbitMQPublisher
from infrastructure.brokers.rabbitmq.config import RabbitMQConfig

# %%
def run_publisher(command, config):

    publisher = RabbitMQPublisher(config)
    publisher.publish(command)

# %%
rabbitmq_config = RabbitMQConfig(port=5673)

# %%
_command = {
    "type": "load_camera",
    "payload": {
        "camera_id": "001",
        "source": "https://www.youtube.com/watch?v=WPMgP2C3_co"
    }
}
run_publisher(_command, rabbitmq_config)

# %%
_command = {
 "type": "add_pipeline",
 "payload": {
   "camera_id": "001",
   "pipeline_name": "truck_counter",
   "rois": [{
     "roi_id": "roi_1",
     "roi_name": "entry_lane",
     "polygon": [[0,540],[1040,540],[1040,720],[0,720]]
   }]
 }
}
run_publisher(_command, rabbitmq_config)

# %%
_command = {
  "type": "update_roi",
  "payload": {
    "camera_id": "001",
    "pipeline_name": "truck_counter",
    "roi": {
      "roi_id": "roi_1",
      "roi_name": "entry_lane",
      "polygon": [[700,150],[1000,150],[1250,300],[1250,720],[700,720]]
    }
  }
}
run_publisher(_command, rabbitmq_config)

# %%
_command = {
 "type": "add_pipeline",
 "payload": {
   "camera_id": "001",
   "pipeline_name": "truck_counter",
   "rois": [{
     "roi_id": "roi_2",
     "roi_name": "entry_lane",
     "polygon": [[0,540],[1040,540],[1040,720],[0,720]]
   }]
 }
}
run_publisher(_command, rabbitmq_config)

# %%
_command = {
  "type": "update_roi",
  "payload": {
    "camera_id": "001",
    "pipeline_name": "truck_counter",
    "roi": {
      "roi_id": "roi_2",
      "roi_name": "entry_lane",
      "polygon": [[0,150],[700,150],[700,720],[0,720]]
    }
  }
}
run_publisher(_command, rabbitmq_config)

# %%
_command = {
  "type": "update_config",
  "payload": {
    "camera_id": "001",
    "pipeline_name": "truck_counter",
    "configs": {
      "detector": {
        "conf": 0.35,
        "iou": 0.5
      }
    }
  }
}
run_publisher(_command, rabbitmq_config)
