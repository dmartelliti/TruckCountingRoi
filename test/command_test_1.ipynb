# %%
import json
from infrastructure.brokers.rabbitmq.publisher import RabbitMQPublisher
from infrastructure.brokers.rabbitmq.config import RabbitMQConfig

# %%
def run_publisher(command, config):

    publisher = RabbitMQPublisher(config)
    publisher.publish(command)

# %%
rabbitmq_config = RabbitMQConfig(port=5673)

# %%
_command = {
    "type": "load_camera",
    "payload": {
        "camera_id": "001",
        "source": "https://youtu.be/1EiC9bvVGnk"
    }
}
run_publisher(_command, rabbitmq_config)

# %%
_command = {
 "type": "add_pipeline",
 "payload": {
   "camera_id": "001",
   "pipeline_name": "truck_counter",
   "rois": [{
     "roi_id": "roi_1",
     "roi_name": "entry_lane",
     "polygon": [[0,540],[1920,540],[1920,1080],[0,1080]]
   }]
 }
}
run_publisher(_command, rabbitmq_config)

# %%
_command = {
  "type": "update_roi",
  "payload": {
    "camera_id": "001",
    "pipeline_name": "truck_counter",
    "roi": {
      "roi_id": "roi_1",
      "roi_name": "entry_lane",
      "polygon": [[1500,600],[1890,600],[1850,1080],[300,1080]]
    }
  }
}
run_publisher(_command, rabbitmq_config)

# %%
_command = {
 "type": "add_pipeline",
 "payload": {
   "camera_id": "001",
   "pipeline_name": "truck_counter",
   "rois": [{
     "roi_id": "roi_2",
     "roi_name": "entry_lane",
     "polygon": [[500,800],[700,800],[1850,1080],[300,1080]]
   }]
 }
}
run_publisher(_command, rabbitmq_config)

# %%
_command = {
  "type": "update_roi",
  "payload": {
    "camera_id": "001",
    "pipeline_name": "truck_counter",
    "roi": {
      "roi_id": "roi_2",
      "roi_name": "entry_lane",
      "polygon": [[0,800],[900,600],[1500,600],[450,1080],[0,1080]]
    }
  }
}
run_publisher(_command, rabbitmq_config)

# %%
_command = {
  "type": "update_config",
  "payload": {
    "camera_id": "001",
    "pipeline_name": "truck_counter",
    "configs": {
      "detector": {
        "conf": 0.35,
        "iou": 0.5
      }
    }
  }
}
run_publisher(_command, rabbitmq_config)
