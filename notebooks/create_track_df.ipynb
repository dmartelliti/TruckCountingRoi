# %%
import sys
sys.path.append('/Users/danielmartelliti/Documents/dany/projects/TruckCountingRoi')

# %%
from application.video_source import VideoSource
from core.utils.tracking_detector import TrackingDetector
from core.utils.track_manager import TrackManager

# %%
video = VideoSource("/Users/danielmartelliti/Documents/dany/projects/TruckCountingRoi/data/vehicle-counting.mp4")
video.open()

tracking_detector = TrackingDetector(model_name="yolov8n.pt")
track_manager = TrackManager(window=5000)
frame_id = 0
dets = []

while True:
    frame = video.read_frame()
    if frame is None:
        continue
    detections = tracking_detector.process(frame, frame_id=frame_id)
    track_history = track_manager.add(detections)
# Out:
# [TrackingDetector] CUDA NOT available — falling back to CPU
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 13
#      11 if frame is None:
#      12     continue
# ---> 13 detections = tracking_detector.process(frame, frame_id=frame_id)
#      14 track_history = track_manager.add(detections)
#
# File ~/Documents/dany/projects/TruckCountingRoi/core/utils/tracking_detector.py:58, in TrackingDetector.process(self, image, offset, frame_id)
#      55 def process(self, image: np.ndarray, offset: Optional[tuple] = None, frame_id: Optional[int] = None)\
#      56         -> DetectionsDto:
# ---> 58     result = self.predict(image)
#      59     detections = DetectionsDto(frame_id=frame_id)
#      61     if result.boxes is None or len(result.boxes) == 0:
#
# File ~/Documents/dany/projects/TruckCountingRoi/core/utils/tracking_detector.py:44, in TrackingDetector.predict(self, image)
#      43 def predict(self, image: np.ndarray) -> Results:
# ---> 44     results = self.model.track(
#      45         source=image,
#      46         classes=self.vehicle_classes,
#      47         tracker=self.tracker_cfg,
#      48         persist=True,
#      49         verbose=False,
#      50         device=self.device,
#      51     )
#      53     return results[0]
#
# File ~/tracker_test/lib/python3.11/site-packages/ultralytics/engine/model.py:579, in Model.track(self, source, stream, persist, **kwargs)
#     577 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     578 kwargs["mode"] = "track"
# --> 579 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~/tracker_test/lib/python3.11/site-packages/ultralytics/engine/model.py:536, in Model.predict(self, source, stream, predictor, **kwargs)
#     534 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535     self.predictor.set_prompts(prompts)
# --> 536 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/tracker_test/lib/python3.11/site-packages/ultralytics/engine/predictor.py:225, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     223     return self.stream_inference(source, model, *args, **kwargs)
#     224 else:
# --> 225     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/tracker_test/lib/python3.11/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/tracker_test/lib/python3.11/site-packages/ultralytics/engine/predictor.py:330, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     328 # Inference
#     329 with profilers[1]:
# --> 330     preds = self.inference(im, *args, **kwargs)
#     331     if self.args.embed:
#     332         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/tracker_test/lib/python3.11/site-packages/ultralytics/engine/predictor.py:182, in BasePredictor.inference(self, im, *args, **kwargs)
#     176 """Run inference on a given image using the specified model and arguments."""
#     177 visualize = (
#     178     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     179     if self.args.visualize and (not self.source_type.tensor)
#     180     else False
#     181 )
# --> 182 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/tracker_test/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/tracker_test/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/tracker_test/lib/python3.11/site-packages/ultralytics/nn/autobackend.py:717, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     715 # PyTorch
#     716 if self.pt or self.nn_module:
# --> 717     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     719 # TorchScript
#     720 elif self.jit:
#
# File ~/tracker_test/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/tracker_test/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/tracker_test/lib/python3.11/site-packages/ultralytics/nn/tasks.py:142, in BaseModel.forward(self, x, *args, **kwargs)
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
#     141     return self.loss(x, *args, **kwargs)
# --> 142 return self.predict(x, *args, **kwargs)
#
# File ~/tracker_test/lib/python3.11/site-packages/ultralytics/nn/tasks.py:159, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     157 if augment:
#     158     return self._predict_augment(x)
# --> 159 return self._predict_once(x, profile, visualize, embed)
#
# File ~/tracker_test/lib/python3.11/site-packages/ultralytics/nn/tasks.py:181, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     179 if profile:
#     180     self._profile_one_layer(m, x, dt)
# --> 181 x = m(x)  # run
#     182 y.append(x if m.i in self.save else None)  # save output
#     183 if visualize:
#
# File ~/tracker_test/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/tracker_test/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/tracker_test/lib/python3.11/site-packages/ultralytics/nn/modules/head.py:151, in Detect.forward(self, x)
#     147 def forward(
#     148     self, x: list[torch.Tensor]
#     149 ) -> dict[str, torch.Tensor] | torch.Tensor | tuple[torch.Tensor, dict[str, torch.Tensor]]:
#     150     """Concatenates and returns predicted bounding boxes and class probabilities."""
# --> 151     preds = self.forward_head(x, **self.one2many)
#     152     if self.end2end:
#     153         x_detach = [xi.detach() for xi in x]
#
# File ~/tracker_test/lib/python3.11/site-packages/ultralytics/nn/modules/head.py:144, in Detect.forward_head(self, x, box_head, cls_head)
#     142 bs = x[0].shape[0]  # batch size
#     143 boxes = torch.cat([box_head[i](x[i]).view(bs, 4 * self.reg_max, -1) for i in range(self.nl)], dim=-1)
# --> 144 scores = torch.cat([cls_head[i](x[i]).view(bs, self.nc, -1) for i in range(self.nl)], dim=-1)
#     145 return dict(boxes=boxes, scores=scores, feats=x)
#
# KeyboardInterrupt:

# %%
track_history.
# Out:
# TrackDataFrameDto(df=     frame_id timestamp track_id  \
# 0           0      None        1
# 1           0      None       68
# 2           0      None       20
# 3           0      None       68
# 4           0      None       68
# ...       ...       ...      ...
# 5464        0      None       68
# 5465        0      None       68
# 5466        0      None       68
# 5467        0      None       68
# 5468        0      None       68
#
#                                               detection
# 0     DetectionDto(bbox=BBoxDto(x1=2941.142578125, y...
# 1     DetectionDto(bbox=BBoxDto(x1=833.9186401367188...
# 2     DetectionDto(bbox=BBoxDto(x1=2259.81591796875,...
# 3     DetectionDto(bbox=BBoxDto(x1=835.7593994140625...
# 4     DetectionDto(bbox=BBoxDto(x1=833.958984375, y1...
# ...                                                 ...
# 5464  DetectionDto(bbox=BBoxDto(x1=833.9511108398438...
# 5465  DetectionDto(bbox=BBoxDto(x1=833.9412231445312...
# 5466  DetectionDto(bbox=BBoxDto(x1=833.9534912109375...
# 5467  DetectionDto(bbox=BBoxDto(x1=833.9317016601562...
# 5468  DetectionDto(bbox=BBoxDto(x1=833.9595947265625...
#
# [5469 rows x 4 columns])
